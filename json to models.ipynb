# %%
"sbsy_data.json"

# %%
import json
with open('sbsy_data.json', encoding='utf-8') as data_file:
    json_data = json.loads(data_file.read())

# %%
import json
with open('sbsy_data.json', encoding='utf-8') as data_file:
    json_data = json.loads(data_file.read())

# %%
json_data
# Out:
# [{'model': 'contenttypes.contenttype',
#   'pk': 1,
#   'fields': {'app_label': 'admin', 'model': 'logentry'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 2,
#   'fields': {'app_label': 'auth', 'model': 'permission'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 3,
#   'fields': {'app_label': 'auth', 'model': 'group'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 4,
#   'fields': {'app_label': 'auth', 'model': 'user'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 5,
#   'fields': {'app_label': 'contenttypes', 'model': 'contenttype'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 6,
#   'fields': {'app_label': 'sessions', 'model': 'session'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 7,
#   'fields': {'app_label': 'school', 'model': 'attendance'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 8,
#   'fields': {'app_label': 'school', 'model': 'attendance_api'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 9,
#   'fields': {'app_label': 'school', 'model': 'classmaster'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 10,
#   'fields': {'app_label': 'school', 'model': 'divisionmaster'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 11,
#   'fields': {'app_label': 'school', 'model': 'mediummaster'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 12,
#   'fields': {'app_label': 'school', 'model': 'ownermaster'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 13,
#   'fields': {'app_label': 'school', 'model': 'parentsmaster'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 14,
#   'fields': {'app_label': 'school', 'model': 'schoolmaster'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 15,
#   'fields': {'app_label': 'school', 'model': 'staffmaster'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 16,
#   'fields': {'app_label': 'school', 'model': 'studentmaster'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 17,
#   'fields': {'app_label': 'school', 'model': 'notice_board_school'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 18,
#   'fields': {'app_label': 'school', 'model': 'school_transport'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 19,
#   'fields': {'app_label': 'school', 'model': 'school_library'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 20,
#   'fields': {'app_label': 'school', 'model': 'school_holiday'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 21,
#   'fields': {'app_label': 'school', 'model': 'message_pack'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 22,
#   'fields': {'app_label': 'school', 'model': 'quary_form'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 23,
#   'fields': {'app_label': 'school', 'model': 'user_command'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 24,
#   'fields': {'app_label': 'school', 'model': 'gpsrestapi'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 25,
#   'fields': {'app_label': 'school', 'model': 'bikeapi'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 26,
#   'fields': {'app_label': 'school', 'model': 'pumpapi'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 27,
#   'fields': {'app_label': 'school', 'model': 'bike_user'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 28,
#   'fields': {'app_label': 'school', 'model': 'school_machine_api'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 29,
#   'fields': {'app_label': 'school', 'model': 'school_machine_details'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 30,
#   'fields': {'app_label': 'school', 'model': 'school_machine_update'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 31,
#   'fields': {'app_label': 'school', 'model': 'bike_user_details'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 32,
#   'fields': {'app_label': 'school', 'model': 'posts'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 33,
#   'fields': {'app_label': 'school', 'model': 'busmap'}},
#  {'model': 'contenttypes.contenttype',
#   'pk': 34,
#   'fields': {'app_label': 'school', 'model': 'busapi'}},
#  {'model': 'sessions.session',
#   'pk': '036arsf99grfrzto7znrsip37bblwajb',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kgn1E:URCaMIVY4hK6otZ5qW15_s3peAATNcc1Sr55AN4Yirc',
#    'expire_date': '2020-12-06T10:54:56.390Z'}},
#  {'model': 'sessions.session',
#   'pk': '04fkntaguqzuyxkc756djf0gy4kn0ldp',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1ltDDR:XYInQCqYHukmbxjPbrM19UdTWQV9qg0uOkyMfeTUqHg',
#    'expire_date': '2021-06-29T17:51:09.721Z'}},
#  {'model': 'sessions.session',
#   'pk': '058dun8ar2eve437y93g7h3toyhqoq6b',
#   'fields': {'session_data': '.eJxVjMEOwiAQRP-FsyHbwlLw6N1vaBZYpGogKe3J-O9K0oPeJvPezEvMtG953huv8xLFWQzi9Nt5Cg8uHcQ7lVuVoZZtXbzsijxok9ca-Xk53L-DTC1_18Ylz1PygIMFIgtgA43OETIZpxkAHVqFSRkCzTqiskhDT2oaA4j3B9nNNz8:1lVCFc:Co7yGGSQc4DsZavFGiHD_UzOyesfBYRathhCziuPnqk',
#    'expire_date': '2021-04-24T11:58:08.740Z'}},
#  {'model': 'sessions.session',
#   'pk': '0fj67a2pcju13w8w257vceiyu69wkf8z',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kjeMa:t4hjEH5-IQXvNQA38k7DWbXtJpV2fUP_IyxBklbz5UE',
#    'expire_date': '2020-12-14T08:16:48.015Z'}},
#  {'model': 'sessions.session',
#   'pk': '0mt42mssvtpr7c4912z3s0aotzoxbhip',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lJqdH:1gRSTh5P4LLvk38mXo2Fr06ijoiv7fMW576BHlnVnLc',
#    'expire_date': '2021-03-24T04:39:39.541Z'}},
#  {'model': 'sessions.session',
#   'pk': '0nimag47jsax6gjrz5f6j50xjoy0o1ld',
#   'fields': {'session_data': '.eJxVjEsOAiEQBe_C2hDA5qNL956BNHQjowaSYWZlvLtOMgvdvqp6LxFxXWpcB89xInEWEJQ4_K4J84PbhuiO7dZl7m2ZpyQ3Re50yGsnfl529--g4qjf2iajWCF578hwMq6A8vqImpnxxICGknVYcgAAzJQDafDFWWVD0M6L9wdHMjiW:1lNYCd:3zNum8yNAhorFs0LZLRUdKUMXpOzNIJ9J6CIoZ56t14',
#    'expire_date': '2021-04-03T09:47:27.486Z'}},
#  {'model': 'sessions.session',
#   'pk': '0wchv6y90q13epa37mzhwo5fcmic730i',
#   'fields': {'session_data': '.eJxVjDsOwyAQBe9CHSHAYNYp0_sMaGGX4CQCyZ8qyt1jSy6S9s3Me4uA21rCtvAcJhJXoWEQl981YnpyPRA9sN6bTK2u8xTlociTLnJsxK_b6f4dFFzKXkMm1w0WVKSc-wjWsI-krUkdQk-8A6uT8Q60Th4AFTrHQ5dIeZORxecLOb84eQ:1lABZe:DNmlGqECPOtVeux6pinzeNKxZvjbsvkuHL8i_ZlUyIw',
#    'expire_date': '2021-02-25T12:59:58.571Z'}},
#  {'model': 'sessions.session',
#   'pk': '17c7dnb7wzskxibi90ztvsd02528e5h1',
#   'fields': {'session_data': '.eJxVjDkOwjAUBe_iGlnGeyjpcwbLfzEOIFvKUiHuDpFSQPtm5r1Eytta07bwnCYSF3E2Tpx-V8j44LYjuud26xJ7W-cJ5K7Igy5y7MTP6-H-HdS81G8drY9sMGDmmB0hky_G6Ki1DsCmFMWWIqgAg_KAwVlNdvDRKQcOwyDeH0GuOFA:1lMR6R:XLariByfRPpvq5LSB5_XlZ9RFCyckNVCxMjKhY551G8',
#    'expire_date': '2021-03-31T08:00:27.461Z'}},
#  {'model': 'sessions.session',
#   'pk': '17ixxivefzrqmdazqx08pp73nmm01tq6',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lGDdc:TauoRKLCcQD3SE63R1kA55g9lqFb28oh7AyFBvH4VAc',
#    'expire_date': '2021-03-14T04:25:00.537Z'}},
#  {'model': 'sessions.session',
#   'pk': '1mih1thqgtagm4l8v6pjy648k2p1y22c',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1knATB:SdAEpT3MPIJ9jjvizHQRWpqy1j-ri0psxaoZ15cEmnY',
#    'expire_date': '2020-12-24T01:10:09.191Z'}},
#  {'model': 'sessions.session',
#   'pk': '1tis81z6f594ijhzhz2mjwdtxhguelv5',
#   'fields': {'session_data': 'NjJhNjc2ZjQ3YjNhYjUwNDExNDVjZTYwMjgxNTkwM2JlYTBmZDg1Mjp7Il9hdXRoX3VzZXJfaWQiOiIxMCIsIl9hdXRoX3VzZXJfYmFja2VuZCI6ImRqYW5nby5jb250cmliLmF1dGguYmFja2VuZHMuTW9kZWxCYWNrZW5kIiwiX2F1dGhfdXNlcl9oYXNoIjoiNTgwZDE2MjgwOWU3MzI3ZjJlMzg5ZjU3ODk2NTE0N2Q0YjE3MjQ3MiJ9',
#    'expire_date': '2020-09-13T06:34:56.176Z'}},
#  {'model': 'sessions.session',
#   'pk': '1tryz6lymgevkyi1gcz26y5ztp0clyai',
#   'fields': {'session_data': '.eJxVjMEOwiAQRP-FsyHiLhQ8evcbyC6sUjU0Ke3J-O_SpAc9TfLmzbxVpHUpcW0yxzGrs0JQh1_IlJ5StyY_qN4nnaa6zCPrTdF72_R1yvK67O7fQaFW-lqSlxBuR_LAbAcCEsumB4ZkOjOAFhMN4AwKQ-jYWXQkJ4cdefX5AhfgN6g:1l9ovs:xb_19lDJwz-oPcIlKF4DUBSyMJ7EH4XE5rhyFg6JcKk',
#    'expire_date': '2021-02-24T12:49:24.885Z'}},
#  {'model': 'sessions.session',
#   'pk': '1v166fv65lidnt3icqnrrw8cqav2ua0e',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lHUTb:-Yd3a4dAQeIRmoEYKMN_geu4K4Nrs3AMlxA1Gp_wHbs',
#    'expire_date': '2021-03-17T16:35:55.651Z'}},
#  {'model': 'sessions.session',
#   'pk': '29uvh4ndtknyliv9m4koz7dk5y90mic4',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1lJE7M:6sMLAW-gHbghnUmu5A-Uczg_4ZHzKo5i6XqcIhWktLQ',
#    'expire_date': '2021-03-22T11:32:08.261Z'}},
#  {'model': 'sessions.session',
#   'pk': '2c4cam8vj06xdsubxq737umd49v0mcgf',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lG8HV:IL_aNQ56NHOWuPvWnd6QrFBiXttjgDoD-pxqcuxQlIM',
#    'expire_date': '2021-03-13T22:41:49.046Z'}},
#  {'model': 'sessions.session',
#   'pk': '2fb1t67d93rqiggsnntzpsyxrwo53ixw',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1l8lDC:B6meK2rzGSZ2dSNq-IPj8l7LaxAfpBZyNCkOGoU7Ue4',
#    'expire_date': '2021-02-21T14:38:54.618Z'}},
#  {'model': 'sessions.session',
#   'pk': '2h55y2exm0gyokht8w9o41ddahi1v8ue',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1klpCK:qktZMyN3PqsuQaMTJ1RJ7IRgYkKUY_H_2Ei8f29i3ks',
#    'expire_date': '2020-12-20T08:15:12.363Z'}},
#  {'model': 'sessions.session',
#   'pk': '2jg7omvgzwsfw4bxykt18etd66j30gse',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1l8PxR:ajo2wSwRYfq-P3_8pckdT8vRZa_yx4y9Vwpb5-S3YXw',
#    'expire_date': '2021-02-20T15:57:13.206Z'}},
#  {'model': 'sessions.session',
#   'pk': '2odye7kg0y6ltf1kdktmzepwq92fgsrx',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1knAT9:x4f05MrCGIDfehe0fsNjk94FtUFEvx2EDi27rbicdbA',
#    'expire_date': '2020-12-24T01:10:07.267Z'}},
#  {'model': 'sessions.session',
#   'pk': '31h60ybri49ztl5ec3u3pdpv7yx1pwez',
#   'fields': {'session_data': 'NjM2M2QxODFkYmI3YjEzM2RmZTk1NDQ4ODc2MzA3NGFhZjBiMmEyNzp7Il9hdXRoX3VzZXJfaWQiOiIyIiwiX2F1dGhfdXNlcl9iYWNrZW5kIjoiZGphbmdvLmNvbnRyaWIuYXV0aC5iYWNrZW5kcy5Nb2RlbEJhY2tlbmQiLCJfYXV0aF91c2VyX2hhc2giOiJhZDZlMzEzNzNiYTE1ZDAzZmE2OTI3NTY1ZjdlMTcyZjAwZTA4ZWRjIn0=',
#    'expire_date': '2020-09-07T08:33:43.569Z'}},
#  {'model': 'sessions.session',
#   'pk': '31pwp1t6sb1lgmzrg7hlp2l0mm8auh10',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kuf1J:-zEHvYqKQc52bT9WbXFcV-xmo8El3JiwjIoGtd1Bzpg',
#    'expire_date': '2021-01-13T17:12:21.640Z'}},
#  {'model': 'sessions.session',
#   'pk': '336tjr32gjnorlcy6ivxolv48efbyq07',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1lA8tK:jkDYEE7cnErDnRw3xZo96DT2Ue_rKtI2ugy5B3HeORM',
#    'expire_date': '2021-02-25T10:08:06.414Z'}},
#  {'model': 'sessions.session',
#   'pk': '38i1bbq9ycwvgi0euyzeyugn3agdzxve',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kTTRJ:D22a0Od-P0nOqel3To5gyazc1q0nSjAqIg1Q7QbRDHY',
#    'expire_date': '2020-10-30T17:22:49.348Z'}},
#  {'model': 'sessions.session',
#   'pk': '436yzaxppuw7l3amdf1kil40pmo7fdq4',
#   'fields': {'session_data': 'NjM2M2QxODFkYmI3YjEzM2RmZTk1NDQ4ODc2MzA3NGFhZjBiMmEyNzp7Il9hdXRoX3VzZXJfaWQiOiIyIiwiX2F1dGhfdXNlcl9iYWNrZW5kIjoiZGphbmdvLmNvbnRyaWIuYXV0aC5iYWNrZW5kcy5Nb2RlbEJhY2tlbmQiLCJfYXV0aF91c2VyX2hhc2giOiJhZDZlMzEzNzNiYTE1ZDAzZmE2OTI3NTY1ZjdlMTcyZjAwZTA4ZWRjIn0=',
#    'expire_date': '2020-09-21T17:06:47.892Z'}},
#  {'model': 'sessions.session',
#   'pk': '45mqp8su2w62110xcmuldy7ggk4u1fbr',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1l8Ecg:Yl_2vS15Q-6VdYZSCEuCUSD4zIcAPgDQQWwBnA2GcJc',
#    'expire_date': '2021-02-20T03:51:02.340Z'}},
#  {'model': 'sessions.session',
#   'pk': '49y0dlnwdkre6vx7hrv3l8g2xny7oqrx',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1l8oJi:KQgX_7rCHb-prVt34SSXsow4pzY_VczDOOtHWERYKVo',
#    'expire_date': '2021-02-21T17:57:50.876Z'}},
#  {'model': 'sessions.session',
#   'pk': '4ds6d04mczdk3etrflgo8mhp4cowv8go',
#   'fields': {'session_data': 'OWI0NGJhMGJhOWRhYzQyZjVkMTk5ZTJhZmUwNDNmZTg0N2EwN2I4ZTp7Il9hdXRoX3VzZXJfaWQiOiI0MSIsIl9hdXRoX3VzZXJfYmFja2VuZCI6ImRqYW5nby5jb250cmliLmF1dGguYmFja2VuZHMuTW9kZWxCYWNrZW5kIiwiX2F1dGhfdXNlcl9oYXNoIjoiYzNiZmFiZTc1YTM1NTExNGZlMTE4YTU5NDE4ZGFmZThjYzJhMGM2YyJ9',
#    'expire_date': '2020-10-19T07:50:27.349Z'}},
#  {'model': 'sessions.session',
#   'pk': '4eg5bbg2q8c55pns7mvmd9mqz3i3ktyo',
#   'fields': {'session_data': '.eJxVjMEOwiAQRP-FsyHbwlLw6N1vaBZYpGogKe3J-O9K0oPeJvPezEvMtG953huv8xLFWQzi9Nt5Cg8uHcQ7lVuVoZZtXbzsijxok9ca-Xk53L-DTC1_18Ylz1PygIMFIgtgA43OETIZpxkAHVqFSRkCzTqiskhDT2oaA4j3B9nNNz8:1lNYFh:6NPNqKyVAY3rKsuiJWo1QpVBP8U9SBxiQGHL2JnGfig',
#    'expire_date': '2021-04-03T09:50:37.285Z'}},
#  {'model': 'sessions.session',
#   'pk': '4lgurtogfroi4mlej7i6obd7trlb1bzq',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1l7cFW:5J-RrQlVmZQekbg7SHIac9XMLufQJD0XmsObCepjfNI',
#    'expire_date': '2021-02-18T10:52:34.905Z'}},
#  {'model': 'sessions.session',
#   'pk': '4qt6opy1rmb46jtk4pi1h48zpmhqnb9t',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1knAT9:x4f05MrCGIDfehe0fsNjk94FtUFEvx2EDi27rbicdbA',
#    'expire_date': '2020-12-24T01:10:07.174Z'}},
#  {'model': 'sessions.session',
#   'pk': '5ntesdmzjqo287xhaaabowzq3filv8lk',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1lFHXv:OyLaACJlZo0SfS2tibjSjNl1H0Y7ab0wfpWrQFqEOos',
#    'expire_date': '2021-03-11T14:23:15.972Z'}},
#  {'model': 'sessions.session',
#   'pk': '5tcvmzta79okzl5kwt071k6d24mmncez',
#   'fields': {'session_data': 'NDU2MGZkMjc3YmM2OWIwMWU5NTRjMjIxYTE1NjU0MTU3Yzc2N2MzZTp7Il9hdXRoX3VzZXJfaWQiOiIyIiwiX2F1dGhfdXNlcl9iYWNrZW5kIjoiZGphbmdvLmNvbnRyaWIuYXV0aC5iYWNrZW5kcy5Nb2RlbEJhY2tlbmQiLCJfYXV0aF91c2VyX2hhc2giOiJkMGY0MjAxZGJhNDliN2JmNWI5YWFjYzFhZjQzMjcxZmJkOGUzNGEwIn0=',
#    'expire_date': '2020-10-05T15:25:35.663Z'}},
#  {'model': 'sessions.session',
#   'pk': '5vaytzoti8uhilf15bd1zq360ar3es3f',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGlne9Qebkj5nsNY_HEC2FCcV4u4QKQW0b2bei3na1uq3kRc_J3ZhYBw7_a6B4iO3HaU7tVvnsbd1mQPfFX7Qwaee8vN6uH8HlUb91lmTOxuLwloVolGgZUR0yhi0RqEAC6EkkkVbVRRSFqVEhKAlCQE6s_cH_2o3RA:1lLTzS:g9qdgDjwsM_VZQTzSos1aov8ZnYXtNh3vG6RmhLEF1k',
#    'expire_date': '2021-03-28T16:53:18.198Z'}},
#  {'model': 'sessions.session',
#   'pk': '5yc4t5h66syy7radvv8ttl6l0q8y1bta',
#   'fields': {'session_data': 'YjBkZGM5ZDc0YzE1NGZhMTIyZDQzNzBlMWIxNWUzOTkzMWJiMzI2Mzp7Il9hdXRoX3VzZXJfaWQiOiIxIiwiX2F1dGhfdXNlcl9iYWNrZW5kIjoiZGphbmdvLmNvbnRyaWIuYXV0aC5iYWNrZW5kcy5Nb2RlbEJhY2tlbmQiLCJfYXV0aF91c2VyX2hhc2giOiI2MmYzZTcyNTFhNDUzMWY4ZjBmYTg5MTU4OWMxZjc2NDRlYTA2MDVkIn0=',
#    'expire_date': '2020-09-29T18:13:26.459Z'}},
#  {'model': 'sessions.session',
#   'pk': '65eaxnatww902miqslqikuvgb8c3tukc',
#   'fields': {'session_data': '.eJxVjMEOwiAQRP-FsyHbwlLw6N1vaBZYpGogKe3J-O9K0oPeJvPezEvMtG953huv8xLFWQzi9Nt5Cg8uHcQ7lVuVoZZtXbzsijxok9ca-Xk53L-DTC1_18Ylz1PygIMFIgtgA43OETIZpxkAHVqFSRkCzTqiskhDT2oaA4j3B9nNNz8:1lVAtv:UkFBN4DcCCgsD-IFUziRRpHu2-p6Wfk1TygesbquMI4',
#    'expire_date': '2021-04-24T10:31:39.972Z'}},
#  {'model': 'sessions.session',
#   'pk': '6fj9w3t5utyhxr4ycnwpzubzcju7l56n',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1l7b7I:2dDrNwTT7-p90dFsWCwpAVbGcZXapBstq-fV6CeTgiU',
#    'expire_date': '2021-02-18T09:40:00.082Z'}},
#  {'model': 'sessions.session',
#   'pk': '7ccioo81158p2qya5cl3piu71xdli6g3',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGln-xD9Kes5grXc3OIAcKU4qxN0hUgpo38y8l8iwrTVvnZc8kTgL7Y04_a4F8MFtR3SHdpslzm1dpiJ3RR60y-tM_Lwc7t9BhV6_dfLGpBFstBgUESEGX0wo4AZvOXhyjDAEnYoySKiTcoos0JiYYiws3h84xjkA:1l9lW1:XoleehXwQLqKj1VN7PGlXZxsXGg7IOyi1gtPIegpiXM',
#    'expire_date': '2021-02-24T09:10:29.287Z'}},
#  {'model': 'sessions.session',
#   'pk': '7k4mp6a4ka82xtn4tljjkwz4y6fp5043',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lAxgc:U7hf_HHnZpRnqnURxFbfnxKtxJ6h4b1gDGT78zRzh3Y',
#    'expire_date': '2021-02-27T16:22:22.013Z'}},
#  {'model': 'sessions.session',
#   'pk': '7pf3o7k5cnwp6jdirnkoujd8d3fjwuco',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lIwhl:LHLHKM0mxZyd3JqzXcnob6p_msHaXxSo1136tMouduo',
#    'expire_date': '2021-03-21T16:56:33.312Z'}},
#  {'model': 'sessions.session',
#   'pk': '7s4upr51rerb8drfggwf5psg1c6q5arr',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lBsJ3:SpBYcApjWV6lOWoZOpo-drGZECnzO5udYs_TcNCWtTM',
#    'expire_date': '2021-03-02T04:49:49.051Z'}},
#  {'model': 'sessions.session',
#   'pk': '7u8hvi3rwoodicif5sr9ijg8ibghsc82',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lHUSf:XMsFSldYkkUradHQNAkHnr8tBQ5K4aXGVAtBSwEi5gI',
#    'expire_date': '2021-03-17T16:34:57.360Z'}},
#  {'model': 'sessions.session',
#   'pk': '7yr7qxy5iy5nxcwgw3c91yemczfj2no2',
#   'fields': {'session_data': '.eJxVjDkOwjAUBe_iGlnGeyjpcwbLfzEOIFvKUiHuDpFSQPtm5r1Eytta07bwnCYSF3E2Tpx-V8j44LYjuud26xJ7W-cJ5K7Igy5y7MTP6-H-HdS81G8drY9sMGDmmB0hky_G6Ki1DsCmFMWWIqgAg_KAwVlNdvDRKQcOwyDeH0GuOFA:1lLNKK:_Ofz6NEIEsUDTzt4mUay-Z0ydxA75LTlhLtXmM9q81M',
#    'expire_date': '2021-03-28T09:46:24.525Z'}},
#  {'model': 'sessions.session',
#   'pk': '8586z2m0q4c0xsyokeyeph9o1bpa57r4',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1lJqkT:uvKVLT39rz7CbOrA3PTHOgofhCLf4DVH87_8n7CLlM0',
#    'expire_date': '2021-03-24T04:47:05.936Z'}},
#  {'model': 'sessions.session',
#   'pk': '87huz4m9vw0fae0g2funatgqt99kok1f',
#   'fields': {'session_data': 'NjM2M2QxODFkYmI3YjEzM2RmZTk1NDQ4ODc2MzA3NGFhZjBiMmEyNzp7Il9hdXRoX3VzZXJfaWQiOiIyIiwiX2F1dGhfdXNlcl9iYWNrZW5kIjoiZGphbmdvLmNvbnRyaWIuYXV0aC5iYWNrZW5kcy5Nb2RlbEJhY2tlbmQiLCJfYXV0aF91c2VyX2hhc2giOiJhZDZlMzEzNzNiYTE1ZDAzZmE2OTI3NTY1ZjdlMTcyZjAwZTA4ZWRjIn0=',
#    'expire_date': '2020-09-13T10:20:48.416Z'}},
#  {'model': 'sessions.session',
#   'pk': '8coccl6gomd0wjdtrpnmesjlkuozdryy',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1l75QG:sCJf3XE9-9o-M4BJCQl2IxxqjCfxgxVpEYetnfIva0g',
#    'expire_date': '2021-02-16T23:49:28.029Z'}},
#  {'model': 'sessions.session',
#   'pk': '8p951wn84qw41e17fiz6j06thbllojic',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kaeT1:W-gIndpuxfZFwyQSqPmAHTku1DlHGPakprW_EWyB4X0',
#    'expire_date': '2020-11-19T12:34:15.170Z'}},
#  {'model': 'sessions.session',
#   'pk': '97ayrwzbobetvwg0nolv08cgsf5gvr4w',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1knATB:SdAEpT3MPIJ9jjvizHQRWpqy1j-ri0psxaoZ15cEmnY',
#    'expire_date': '2020-12-24T01:10:09.337Z'}},
#  {'model': 'sessions.session',
#   'pk': '99dc34wr50fc5iub9w0qq8cbjxlk0w7n',
#   'fields': {'session_data': 'NjM2M2QxODFkYmI3YjEzM2RmZTk1NDQ4ODc2MzA3NGFhZjBiMmEyNzp7Il9hdXRoX3VzZXJfaWQiOiIyIiwiX2F1dGhfdXNlcl9iYWNrZW5kIjoiZGphbmdvLmNvbnRyaWIuYXV0aC5iYWNrZW5kcy5Nb2RlbEJhY2tlbmQiLCJfYXV0aF91c2VyX2hhc2giOiJhZDZlMzEzNzNiYTE1ZDAzZmE2OTI3NTY1ZjdlMTcyZjAwZTA4ZWRjIn0=',
#    'expire_date': '2020-09-18T19:20:16.621Z'}},
#  {'model': 'sessions.session',
#   'pk': '9fr7mx2q7cy1qikmoondimge8lox92vf',
#   'fields': {'session_data': '.eJxVjDsOwjAQRO_iGlnxxl9K-pzB2vUHB5AtxUmFuDuJlAK60bw382Yet7X4rafFz5FdmRTs8lsShmeqB4kPrPfGQ6vrMhM_FH7SzqcW0-t2un8HBXvZ1wIsKgPojATIWg3SkkQz5mwSwZ5dIhsDjipIAgEmg6aEUrgh62yRfb70dzgI:1kKdzY:aOqKUzRaDLhq03EDc_oEG_qyD_vLRWgWaXhcOjZWJV4',
#    'expire_date': '2020-10-06T08:49:40.399Z'}},
#  {'model': 'sessions.session',
#   'pk': '9gdpejticqlidvdfil23gmcs4lzo6wrj',
#   'fields': {'session_data': '.eJxVjMEOwiAQRP-FsyHbwlLw6N1vaBZYpGogKe3J-O9K0oPeJvPezEvMtG953huv8xLFWQzi9Nt5Cg8uHcQ7lVuVoZZtXbzsijxok9ca-Xk53L-DTC1_18Ylz1PygIMFIgtgA43OETIZpxkAHVqFSRkCzTqiskhDT2oaA4j3B9nNNz8:1lKGnE:MISCcIBhkTNtJLoaoSljLOgJAYDIg9lusTiT2i-imX0',
#    'expire_date': '2021-03-25T08:35:40.440Z'}},
#  {'model': 'sessions.session',
#   'pk': 'a2bl70qq3p1p90nt2h7x6owz296gzoz3',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1lBtXp:069KKFSZXUKtHJc0F-6DdGy5E-RDJdj4xMXIG_-Gut0',
#    'expire_date': '2021-03-02T06:09:09.373Z'}},
#  {'model': 'sessions.session',
#   'pk': 'a2t43c2m4hcf94q94xl9jzfatthzeix6',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kkIWQ:SLjPCqO9cLO8bjZM7tkpkko9u9ADL-Hy8m02grYaxbo',
#    'expire_date': '2020-12-16T03:09:38.613Z'}},
#  {'model': 'sessions.session',
#   'pk': 'a8xjhdbnitkj40cc2jj5t5h53vj02hzc',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSGFDmNx6b7fQGYYkKqBpI-V8d-1SRe6veec-1KBtrWEbUlzmERdlAGnTr8rU3ykuiO5U701HVtd54n1ruiDLnpskp7Xw_07KLSUbx2JGRxjpDPG3noQtMA8eGs6zuI68B4MEkYRxxmJhXuTMEkeALlT7w9I0zkf:1l9enU:eMYHgYKhQHWucQPnfq7W7g8yfhzjHQXxiGSTN0ButCA',
#    'expire_date': '2021-02-24T02:00:04.256Z'}},
#  {'model': 'sessions.session',
#   'pk': 'ajzhbmi32cun9yziyp9fhlhtc2cbjygz',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lIktN:PW2a1j6WG4hVD2OSq0yzNcIuApwSiLjE2RIhE7xkpzA',
#    'expire_date': '2021-03-21T04:19:45.046Z'}},
#  {'model': 'sessions.session',
#   'pk': 'aot5h8fiyusckehfo3qffjutmeewz0m8',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1l8Sd4:izq8q24MYFj6Qu82CQu5xCBK7wXclyowV_jZm-tlfQY',
#    'expire_date': '2021-02-20T18:48:22.078Z'}},
#  {'model': 'sessions.session',
#   'pk': 'b1uxnfxit6i36j9v917e9vdj7dlj29si',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSFQGB4u3fsNBBhGqgaS0q6M_65NutDtPefcFwtxW2vYRlnCjOzMlBDs9LummB-l7Qjvsd06z72ty5z4rvCDDn7tWJ6Xw_07qHHUb-3N5ISUiSib7MAWS3ECJTSCTg5ydlZ5JI_KaKtRJwWigCdK0pPxgr0_Hls39w:1lMtL8:v2iE3VrgP_Pwe2zV9kMpzp1OtBnKE9-21ClACFALUFg',
#    'expire_date': '2021-04-01T14:09:30.615Z'}},
#  {'model': 'sessions.session',
#   'pk': 'b34dx33f4taeh82xcevwudxz2i0zdc6u',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1knATA:B6eJFfu9nIwIecII-h1-BUmikiISRVSixLdx4CZAvJE',
#    'expire_date': '2020-12-24T01:10:08.494Z'}},
#  {'model': 'sessions.session',
#   'pk': 'b4tu1htyeethpsb0gh8lnl2a6cjgd3lq',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lIUYA:UioCXu8chaCDsUTFFyYTBReoWCqmHk0eIMMZNSkIRhg',
#    'expire_date': '2021-03-20T10:52:46.981Z'}},
#  {'model': 'sessions.session',
#   'pk': 'baixrj97lbh7hr5ct230fix35s4mm6nw',
#   'fields': {'session_data': 'YjBkZGM5ZDc0YzE1NGZhMTIyZDQzNzBlMWIxNWUzOTkzMWJiMzI2Mzp7Il9hdXRoX3VzZXJfaWQiOiIxIiwiX2F1dGhfdXNlcl9iYWNrZW5kIjoiZGphbmdvLmNvbnRyaWIuYXV0aC5iYWNrZW5kcy5Nb2RlbEJhY2tlbmQiLCJfYXV0aF91c2VyX2hhc2giOiI2MmYzZTcyNTFhNDUzMWY4ZjBmYTg5MTU4OWMxZjc2NDRlYTA2MDVkIn0=',
#    'expire_date': '2020-09-14T11:36:32.648Z'}},
#  {'model': 'sessions.session',
#   'pk': 'bbpv85qp7rvhswxurpolh8k3ltw28imx',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kWeHZ:iHkY2hDWEXNqXHvEkgNGtfKL98xzLQluqWo2i7thBLc',
#    'expire_date': '2020-11-08T11:33:53.459Z'}},
#  {'model': 'sessions.session',
#   'pk': 'bhl1zmh6xe5t02qaj8vdqck6zgczc206',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSFQGB4u3fsNBBhGqgaS0q6M_65NutDtPefcFwtxW2vYRlnCjOzMlBDs9LummB-l7Qjvsd06z72ty5z4rvCDDn7tWJ6Xw_07qHHUb-3N5ISUiSib7MAWS3ECJTSCTg5ydlZ5JI_KaKtRJwWigCdK0pPxgr0_Hls39w:1lL4Fb:Uvr7ayUMzQ9Pgtt95BHrxKN_VRbmIlsV2xLQxbG6vDA',
#    'expire_date': '2021-03-27T13:24:15.307Z'}},
#  {'model': 'sessions.session',
#   'pk': 'bmc9p6f8pcrl5p6gs45hsxg1y06tgq51',
#   'fields': {'session_data': '.eJxVjEsOwjAMBe-SNYriYLuEJXvOELlxSgookfpZIe4OlbqA7ZuZ9zJR1qXEdc5THNWcjT925vC79pIeuW5I71JvzaZWl2ns7abYnc722jQ_L7v7d1BkLt-6w8ERK3lVAA7AQD5xIhoQcydAWXNwDsH1pxCS04HRJ0VhZFIv5v0BDzM3pw:1lD0Oz:-BZUeudtHUIAWhENwEr8n3X8qf_CfH9xfs9myCVYJK4',
#    'expire_date': '2021-03-05T07:40:37.166Z'}},
#  {'model': 'sessions.session',
#   'pk': 'bn8y1vgcjfne9fuv9fyp7roo81k8lt66',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kPU8C:ctHXzPBmsXt7antaFl7SFGDoCxuu17t1MuiRMYbTSjA',
#    'expire_date': '2020-10-19T17:18:36.888Z'}},
#  {'model': 'sessions.session',
#   'pk': 'bok7eap0c7mwmlwsz2ogk7jdg3ihrhf7',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1lHTNf:6DkutNHQ3vXLNSerGlyelFaYiix6o4-jCsiC9-wiXY4',
#    'expire_date': '2021-03-17T15:25:43.463Z'}},
#  {'model': 'sessions.session',
#   'pk': 'bqbry721bii4b3nc4xl5zjvii0ml1jfa',
#   'fields': {'session_data': '.eJxVjDkOwjAUBe_iGll27HihpOcMkf9GAsiWslSIu0OkFNC-mXkvNZRtHYdt4XmYSJ1Vl506_a5Q8MF1R3Qv9dY0trrOE-hd0Qdd9LURPy-H-3cwlmX81oCuB0lsXDTEFtBYtMLJZ_EOAvfZ9i4wEkmiIMZmjyXG4LxAV8Sq9wdOOTj-:1lIRbT:T37dUR6bHsCANdns0Qj1XEpJZnI8vWhIlrO6TH7tkns',
#    'expire_date': '2021-03-20T07:43:59.440Z'}},
#  {'model': 'sessions.session',
#   'pk': 'bqsr4pfrnccje46ur5qe8ik1c2h5fbb4',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kVqGW:wqWYbOZuepd8hFm8tgy2cxtoiQiqFl1oBKMbr89O7Ck',
#    'expire_date': '2020-11-06T06:09:28.704Z'}},
#  {'model': 'sessions.session',
#   'pk': 'br5pug5xqa8rt6tvqbe54wwu72tvwzvn',
#   'fields': {'session_data': '.eJxVjMEOwiAQRP-FsyHbwlLw6N1vaBZYpGogKe3J-O9K0oPeJvPezEvMtG953huv8xLFWQzi9Nt5Cg8uHcQ7lVuVoZZtXbzsijxok9ca-Xk53L-DTC1_18Ylz1PygIMFIgtgA43OETIZpxkAHVqFSRkCzTqiskhDT2oaA4j3B9nNNz8:1lNZZW:_eu2s0cJTgPv_yEpXvIV9DlD2_fnroR2IKzKQNr990o',
#    'expire_date': '2021-04-03T11:15:10.411Z'}},
#  {'model': 'sessions.session',
#   'pk': 'bwlu7w0opuu3i556mtd8ot5uvmkxqcgn',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lIlRN:FSvUICFRjTtuef7-IyE5LALMd9fVqiQqVxIblfFMlhI',
#    'expire_date': '2021-03-21T04:54:53.256Z'}},
#  {'model': 'sessions.session',
#   'pk': 'bxrqzojhw5li5bqpzvwyuqn3047h0ijm',
#   'fields': {'session_data': '.eJxVjDsOwyAQBe9CHSHAYNYp0_sMaGGX4CQCyZ8qyt1jSy6S9s3Me4uA21rCtvAcJhJXoWEQl981YnpyPRA9sN6bTK2u8xTlociTLnJsxK_b6f4dFFzKXkMm1w0WVKSc-wjWsI-krUkdQk-8A6uT8Q60Th4AFTrHQ5dIeZORxecLOb84eQ:1lAAya:7Xv8aIrXdOV5J9ai0qW2xMEHsd1O0LFev9dPYqN4tAo',
#    'expire_date': '2021-02-25T12:21:40.840Z'}},
#  {'model': 'sessions.session',
#   'pk': 'bz022axyvu7c4xe0s7qmxnofbk6zf5ef',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSFQGB4u3fsNBBhGqgaS0q6M_65NutDtPefcFwtxW2vYRlnCjOzMlBDs9LummB-l7Qjvsd06z72ty5z4rvCDDn7tWJ6Xw_07qHHUb-3N5ISUiSib7MAWS3ECJTSCTg5ydlZ5JI_KaKtRJwWigCdK0pPxgr0_Hls39w:1lJXxj:9_MpJA3C3TJymTeBq3VB7MHXv5EP0rmr3eq_okjuBEk',
#    'expire_date': '2021-03-23T08:43:31.372Z'}},
#  {'model': 'sessions.session',
#   'pk': 'c3jp0oobyggnvhd5ysbpnlbtx9taeavr',
#   'fields': {'session_data': '.eJxVjEsOAiEQBe_C2hDA5qNL956BNHQjowaSYWZlvLtOMgvdvqp6LxFxXWpcB89xInEWEJQ4_K4J84PbhuiO7dZl7m2ZpyQ3Re50yGsnfl529--g4qjf2iajWCF578hwMq6A8vqImpnxxICGknVYcgAAzJQDafDFWWVD0M6L9wdHMjiW:1lMPp3:46YIxub2vFK_9fNSHfcguuKUilbHkNRg1WcyoTtyFUQ',
#    'expire_date': '2021-03-31T06:38:25.544Z'}},
#  {'model': 'sessions.session',
#   'pk': 'c8drob611l6bf1mqbc5rt4338wy8uci7',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1l7e7C:5Vw-NZjHovzfAxsbRRzvqKLkwsO34a0fFLev9C0WKQU',
#    'expire_date': '2021-02-18T12:52:06.941Z'}},
#  {'model': 'sessions.session',
#   'pk': 'cbfaywi6l4y1lidmteg816x80sm3ibbl',
#   'fields': {'session_data': 'NDU2MGZkMjc3YmM2OWIwMWU5NTRjMjIxYTE1NjU0MTU3Yzc2N2MzZTp7Il9hdXRoX3VzZXJfaWQiOiIyIiwiX2F1dGhfdXNlcl9iYWNrZW5kIjoiZGphbmdvLmNvbnRyaWIuYXV0aC5iYWNrZW5kcy5Nb2RlbEJhY2tlbmQiLCJfYXV0aF91c2VyX2hhc2giOiJkMGY0MjAxZGJhNDliN2JmNWI5YWFjYzFhZjQzMjcxZmJkOGUzNGEwIn0=',
#    'expire_date': '2020-09-30T06:12:30.056Z'}},
#  {'model': 'sessions.session',
#   'pk': 'cfppwfzttrl5ifhvfhswji5vuq1cayb1',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1l7Y9X:_d-LzrmcdjfuYCMwtktnx5mDpkUZiAkqFtPJq6rFdvw',
#    'expire_date': '2021-02-18T06:30:07.660Z'}},
#  {'model': 'sessions.session',
#   'pk': 'coxgv39u5xurkvgv8pbudbkot9kz9u4b',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kUjDF:TasQkw5V9BCT9cEyUoRlVXmuYkdxjEtmbyaEVec8tqA',
#    'expire_date': '2020-11-03T04:25:29.770Z'}},
#  {'model': 'sessions.session',
#   'pk': 'cp3iql1bv9gl0tuawehhxn4tdo0j9301',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kkp1W:wjC705T_FjY08PcRb-ui763MNh5mpzy9LhoT2yzDDD4',
#    'expire_date': '2020-12-17T13:51:54.465Z'}},
#  {'model': 'sessions.session',
#   'pk': 'd666vvbqykvfm6chozfd3g5piqjxo8l5',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kaexm:1g7D3UAy9eaUNTQYk5JAk6FCAdSFK8QhgCP3QDqX3hQ',
#    'expire_date': '2020-11-19T13:06:02.899Z'}},
#  {'model': 'sessions.session',
#   'pk': 'dj2zr8jr5m4kepu7pmg34t2lrlaqj411',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGlne9Qebkj5nsNY_HEC2FCcV4u4QKQW0b2bei3na1uq3kRc_J3ZhYBw7_a6B4iO3HaU7tVvnsbd1mQPfFX7Qwaee8vN6uH8HlUb91lmTOxuLwloVolGgZUR0yhi0RqEAC6EkkkVbVRRSFqVEhKAlCQE6s_cH_2o3RA:1l9n5h:HvojVBe3-CqgPgBDxNUpKtXSViMdfABHnbTbLNn5NHo',
#    'expire_date': '2021-02-24T10:51:25.484Z'}},
#  {'model': 'sessions.session',
#   'pk': 'dkzxt5rqhxz3wy2covhc7kmhtoa4pfj4',
#   'fields': {'session_data': 'NjM2M2QxODFkYmI3YjEzM2RmZTk1NDQ4ODc2MzA3NGFhZjBiMmEyNzp7Il9hdXRoX3VzZXJfaWQiOiIyIiwiX2F1dGhfdXNlcl9iYWNrZW5kIjoiZGphbmdvLmNvbnRyaWIuYXV0aC5iYWNrZW5kcy5Nb2RlbEJhY2tlbmQiLCJfYXV0aF91c2VyX2hhc2giOiJhZDZlMzEzNzNiYTE1ZDAzZmE2OTI3NTY1ZjdlMTcyZjAwZTA4ZWRjIn0=',
#    'expire_date': '2020-09-15T16:56:59.684Z'}},
#  {'model': 'sessions.session',
#   'pk': 'dqnmmy7rupuhmtg0ioko50pvun2640rh',
#   'fields': {'session_data': '.eJxVjMEOwiAQRP-FsyHiLhQ8evcbyC6sUjU0Ke3J-O_SpAc9TfLmzbxVpHUpcW0yxzGrs0JQh1_IlJ5StyY_qN4nnaa6zCPrTdF72_R1yvK67O7fQaFW-lqSlxBuR_LAbAcCEsumB4ZkOjOAFhMN4AwKQ-jYWXQkJ4cdefX5AhfgN6g:1kPOjS:moAEgufRkNvN1tM63P7dJEwOqwEx8hQzTouVHCBqByc',
#    'expire_date': '2020-10-19T11:32:42.913Z'}},
#  {'model': 'sessions.session',
#   'pk': 'dtpz0g8st9vzq9uhzyjjh9wtmblehe1i',
#   'fields': {'session_data': '.eJxVjDkOwjAUBe_iGlnGeyjpcwbLfzEOIFvKUiHuDpFSQPtm5r1Eytta07bwnCYSF3E2Tpx-V8j44LYjuud26xJ7W-cJ5K7Igy5y7MTP6-H-HdS81G8drY9sMGDmmB0hky_G6Ki1DsCmFMWWIqgAg_KAwVlNdvDRKQcOwyDeH0GuOFA:1lD2gu:NjEKQmHK3J27qHlYf8FcyHWz7ciWEt8-z8j6IwqxI_8',
#    'expire_date': '2021-03-05T10:07:16.570Z'}},
#  {'model': 'sessions.session',
#   'pk': 'dvriqeoke9wxqt86b8dmpa2729az9r79',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lL43z:bX5QzOO7xO7mXB5dc7L_QlTANYhFkViuD-62aR1zaUA',
#    'expire_date': '2021-03-27T13:12:15.896Z'}},
#  {'model': 'sessions.session',
#   'pk': 'e1pkjgvx3yt1u1aalamqog1w6mi3l647',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1knATB:SdAEpT3MPIJ9jjvizHQRWpqy1j-ri0psxaoZ15cEmnY',
#    'expire_date': '2020-12-24T01:10:09.228Z'}},
#  {'model': 'sessions.session',
#   'pk': 'e45242cwy69nd9q2ekvpr0w451zspu0w',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSFkeBRcuvcbyMAMUjWQlHZl_Hdt0oVu7znnvkTEba1xG7zEmcRZaG_E6XdNmB_cdkR3bLcuc2_rMie5K_KgQ1478fNyuH8HFUf91k5p6xRgYjJUkBkIg2GnrJ90Np58AFu0MxASQNA2hVIIJrboOWgn3h8yqzgq:1lMl7H:me1z5ymSdCYrr7CwzUd78_6eMKndAzIyGwn3E9417H4',
#    'expire_date': '2021-04-01T05:22:39.161Z'}},
#  {'model': 'sessions.session',
#   'pk': 'e6786k4gt47z36dvywb2vwpp1d5894ec',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1lM2MG:d-JRuroN-SLmLZ-s3KXthFruhQeTBkoLRKofWuT1Fn8',
#    'expire_date': '2021-03-30T05:35:08.062Z'}},
#  {'model': 'sessions.session',
#   'pk': 'ef28dwdp2m63pc1zhmx617eo6wx7kgar',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kaf5T:DUb08igCYhmGKhGCClFauFulTRHx6zef8wVts3jOekw',
#    'expire_date': '2020-11-19T13:13:59.519Z'}},
#  {'model': 'sessions.session',
#   'pk': 'esw1jeysi91or9jpbvqrbcev06vnmrmr',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1lI3Be:XK3G2g-PkM66sni_5nGIoRxG-U3ci8TIoW_gLKeJOtM',
#    'expire_date': '2021-03-19T05:39:42.619Z'}},
#  {'model': 'sessions.session',
#   'pk': 'exw5tobu3d18klcc0rfwi3arqqykdam9',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1l8aQ7:x4_iaNWK15ZSFWyW_aNXucS1xAY0mAEgmyUrugB-rq0',
#    'expire_date': '2021-02-21T03:07:31.122Z'}},
#  {'model': 'sessions.session',
#   'pk': 'f1awlofp43zhq0tfgrakexyyr54nf3r3',
#   'fields': {'session_data': '.eJxVjjsOgzAQRO_iOrKwF_xJmZ4zoPV6HZNEtoShinL3gESRtPPejOYtJtzWPG2Nl2mO4irA9-LymwakJ5cDxQeWe5VUy7rMQR6KPGmTY438up3u30DGlvf24G201tjkwGgwxvgEDgcaODKFTnUuKN0zUkdolLaK9isW-5hAAWgWny8XDzez:1lLcjX:dOoj9Ak7F3JLgJ9bCpf3kem7IgqNMW12dVJhMvjzdpA',
#    'expire_date': '2021-03-29T02:13:27.636Z'}},
#  {'model': 'sessions.session',
#   'pk': 'f2mktowxenji4vhmi5dxtpxbx5kx9o2x',
#   'fields': {'session_data': '.eJxVjEEOwiAQRe_C2hCYKQVcuvcMZIBBqoYmpV0Z765NutDtf-_9lwi0rTVsnZcwZXEWCEacftdI6cFtR_lO7TbLNLd1maLcFXnQLq9z5uflcP8OKvX6rY3mUpx1mNiQH9hFhNFFHdGmkTJZjYV9waSYimcHSlFCYzMMCOBRvD9EHDhx:1lJtnC:N9Al8y6ePnJx_Neb_bGnJavxpUaJlbao30k1M_zxKT0',
#    'expire_date': '2021-03-24T08:02:06.708Z'}},
#  {'model': 'sessions.session',
#   'pk': 'fac3f3i8xche67w0eu7vojn17ieznbi5',
#   'fields': {'session_data': '.eJxVjEEOwiAQAP_C2ZCWwi549N43NLAsUjWQlPZk_Lsh6UGvM5N5i8Ufe16OxtuyRnEVSlx-WfD05NJFfPhyr5Jq2bc1yJ7I0zY518iv29n-DbJvuW9JWYPJowFHyI4IkiWMevCTZRVHwuAAgjMaUA0mBkCYAo-UGDWQ-HwB5Kk39g:1kKR99:-00yDqeSh-6UhFHUyAK10JW9orcjNJyGAk-6bLJNcjM',
#    'expire_date': '2020-10-05T19:06:43.869Z'}},
#  {'model': 'sessions.session',
#   'pk': 'ff25jrvr0pnpx28iyjieriwbe6ixxrm3',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kQMfD:UD08LK4K1UxwYBuD6P0SeSAZovMYan5RA6nyVaOPif4',
#    'expire_date': '2020-10-22T03:32:19.775Z'}},
#  {'model': 'sessions.session',
#   'pk': 'fk425ib7sa2pdnnthx8ldxcz4w5cwrck',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kPQz6:80ry2zppyj0A73sKboGNPToFSe2ivFhmZEUKUcnCPSg',
#    'expire_date': '2020-10-19T13:57:00.685Z'}},
#  {'model': 'sessions.session',
#   'pk': 'fomdxi60xu4yd90j4udcnb9lpse5ak3w',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kVXP1:zzk8st18_zLqPMelb4ZlRn_Cgym_b0xBooypAY3kTIA',
#    'expire_date': '2020-11-05T10:00:59.529Z'}},
#  {'model': 'sessions.session',
#   'pk': 'fs6bwru99q605r8hedfbvxu1gyl188ny',
#   'fields': {'session_data': 'NjM2M2QxODFkYmI3YjEzM2RmZTk1NDQ4ODc2MzA3NGFhZjBiMmEyNzp7Il9hdXRoX3VzZXJfaWQiOiIyIiwiX2F1dGhfdXNlcl9iYWNrZW5kIjoiZGphbmdvLmNvbnRyaWIuYXV0aC5iYWNrZW5kcy5Nb2RlbEJhY2tlbmQiLCJfYXV0aF91c2VyX2hhc2giOiJhZDZlMzEzNzNiYTE1ZDAzZmE2OTI3NTY1ZjdlMTcyZjAwZTA4ZWRjIn0=',
#    'expire_date': '2020-09-18T18:28:38.803Z'}},
#  {'model': 'sessions.session',
#   'pk': 'ftfmfeoo4du68zs1szu9vdmmhfqktfi4',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1l8jIp:24qo_yoQoq0Av5V_FSKfwmlogHETeaxGf2LhEQUF7BM',
#    'expire_date': '2021-02-21T12:36:35.202Z'}},
#  {'model': 'sessions.session',
#   'pk': 'fxvjdrgo8qpdjcmg4h3m86bx7fxmdtrb',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGlne9Qebkj5nsNY_HEC2FCcV4u4QKQW0b2bei3na1uq3kRc_J3ZhYBw7_a6B4iO3HaU7tVvnsbd1mQPfFX7Qwaee8vN6uH8HlUb91lmTOxuLwloVolGgZUR0yhi0RqEAC6EkkkVbVRRSFqVEhKAlCQE6s_cH_2o3RA:1lKyOv:Ln57BkDS7kO84dBIgYFCigDX3hXa66Lyeahu6YtJnXU',
#    'expire_date': '2021-03-27T07:09:29.938Z'}},
#  {'model': 'sessions.session',
#   'pk': 'gmheog6pglnepazy0gpmpxv4nt5wmqpk',
#   'fields': {'session_data': '.eJxVjEEOwiAQAP_C2ZCWwi549N43NLAsUjWQlPZk_Lsh6UGvM5N5i8Ufe16OxtuyRnEVSlx-WfD05NJFfPhyr5Jq2bc1yJ7I0zY518iv29n-DbJvuW9JWYPJowFHyI4IkiWMevCTZRVHwuAAgjMaUA0mBkCYAo-UGDWQ-HwB5Kk39g:1kLU54:CYMoLfOZ7_1NYf4y9r1bPMRRvfdTqP46A71oQSo787g',
#    'expire_date': '2020-10-08T16:26:50.880Z'}},
#  {'model': 'sessions.session',
#   'pk': 'gt1qbuqhf2zn3su2e1qlalx6d14um8gn',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1leFtR:Kvv82dEoWVJydJvQ0ZurJ6CGVwocXGFnC1wr5g3eGHc',
#    'expire_date': '2021-05-19T11:40:41.643Z'}},
#  {'model': 'sessions.session',
#   'pk': 'gz0gtbvfsbnbcwonn5oukovpayape8ee',
#   'fields': {'session_data': '.eJxVjEsOwjAMBe-SNYriYLuEJXvOELlxSgookfpZIe4OlbqA7ZuZ9zJR1qXEdc5THNWcjT925vC79pIeuW5I71JvzaZWl2ns7abYnc722jQ_L7v7d1BkLt-6w8ERK3lVAA7AQD5xIhoQcydAWXNwDsH1pxCS04HRJ0VhZFIv5v0BDzM3pw:1lJVxY:KUUXeUSKTk4DZ0TpyJOcDrAkR6c2UcHEapNvcTCuxLw',
#    'expire_date': '2021-03-23T06:35:12.112Z'}},
#  {'model': 'sessions.session',
#   'pk': 'h2fwp3drgln4tuvxsez5qvjiae3pc1va',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1knATB:SdAEpT3MPIJ9jjvizHQRWpqy1j-ri0psxaoZ15cEmnY',
#    'expire_date': '2020-12-24T01:10:09.509Z'}},
#  {'model': 'sessions.session',
#   'pk': 'hif93qrkl5sigpolgyfy0bw8kth710kk',
#   'fields': {'session_data': '.eJxVjEEOwiAQAP_C2ZCWwi549N43NLAsUjWQlPZk_Lsh6UGvM5N5i8Ufe16OxtuyRnEVSlx-WfD05NJFfPhyr5Jq2bc1yJ7I0zY518iv29n-DbJvuW9JWYPJowFHyI4IkiWMevCTZRVHwuAAgjMaUA0mBkCYAo-UGDWQ-HwB5Kk39g:1kKQyN:EJL_2ZnhaLXbABPOBFzYiLMIaXFpejXVHvoshoZ4rJI',
#    'expire_date': '2020-10-05T18:55:35.378Z'}},
#  {'model': 'sessions.session',
#   'pk': 'hird93n89uky0tmm852d5wuzxezj2y08',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lBt2J:puxjem3QVZsdrvK1M9SL_DceFCDtkUvr0kSjarHBAG8',
#    'expire_date': '2021-03-02T05:36:35.092Z'}},
#  {'model': 'sessions.session',
#   'pk': 'i78dyv1bliql7x8nqyk7uz3jenktgmi7',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSGFDmNx6b7fQGYYkKqBpI-V8d-1SRe6veec-1KBtrWEbUlzmERdlAGnTr8rU3ykuiO5U701HVtd54n1ruiDLnpskp7Xw_07KLSUbx2JGRxjpDPG3noQtMA8eGs6zuI68B4MEkYRxxmJhXuTMEkeALlT7w9I0zkf:1lIv5O:c5r7LkLXZIysvu-7Rlt0ijRVZt20TyQb0OOugf2VyHc',
#    'expire_date': '2021-03-21T15:12:50.796Z'}},
#  {'model': 'sessions.session',
#   'pk': 'i7u2ltknw33xvehiatmxi4c4tzsls9ly',
#   'fields': {'session_data': '.eJxVjMEOwiAQRP-FsyHbwlLw6N1vaBZYpGogKe3J-O9K0oPeJvPezEvMtG953huv8xLFWQzi9Nt5Cg8uHcQ7lVuVoZZtXbzsijxok9ca-Xk53L-DTC1_18Ylz1PygIMFIgtgA43OETIZpxkAHVqFSRkCzTqiskhDT2oaA4j3B9nNNz8:1lVAoJ:GGgUcgcbXhJHB1vKUEom-_D-PRBFCci-3XnTdbE9pg4',
#    'expire_date': '2021-04-24T10:25:51.660Z'}},
#  {'model': 'sessions.session',
#   'pk': 'igulbgfhdn7wiw4ltvs5wjbxt4cvao2s',
#   'fields': {'session_data': '.eJxVjDEOwjAMRe-SGUVR0pCakZ0zRHZskwJqpaadKu4OlTrA-t97fzMZ16XmtcmcBzYX483pdyMsTxl3wA8c75Mt07jMA9ldsQdt9jaxvK6H-3dQsdVvTUXZaUx9EuKICtiJ8Ll4AJZCGqJSVOiUEHwMFJwElwpgrxCiB_P-ADH6OUE:1lABf6:l5WNnGIk6XE63NKUXMgLW3Hoz-8qIXJnmAj-bOM7oUA',
#    'expire_date': '2021-02-25T13:05:36.255Z'}},
#  {'model': 'sessions.session',
#   'pk': 'iiylw3oghdoaoqphhuq0jfzbkmlqydjw',
#   'fields': {'session_data': '.eJxVjMsOwiAQRf-FtSEdHoW6dO83kBkYpGogKe3K-O_apAvd3nPOfYmA21rC1nkJcxJnYUGcfkfC-OC6k3THemsytrouM8ldkQft8toSPy-H-3dQsJdv7SwgZIpxGrzOBEZNaEcNZgBLKkNmzoQpK218RKd49ADGG62ByIMT7w8HdjfB:1l94Hj:myFRRXYfC6TDz2j3_hyveRyBPdbabMMLJSDoBGl_vXg',
#    'expire_date': '2021-02-22T11:00:51.559Z'}},
#  {'model': 'sessions.session',
#   'pk': 'j1tryyaoi8icll6esswfs4r19pa1r1an',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kVYim:VY1HQEspl1NIHIPK8uzgO1ACxSHX1zK9cifJbcCaxRI',
#    'expire_date': '2020-11-05T11:25:28.357Z'}},
#  {'model': 'sessions.session',
#   'pk': 'j51e27on49zx18b39yas9x7wagixlcf3',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kjchX:Q1rLlHSkWpytn5OkE0XZS5qISvcX8aThpbeS81bo5Zo',
#    'expire_date': '2020-12-14T06:30:19.397Z'}},
#  {'model': 'sessions.session',
#   'pk': 'ja4yen8xvagfqbyr3tx31xdrrvgt6c4w',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kPPPo:7exdMWIsXcFCGznMIGr5Ws0QEt-w-QtVkGmExSzX54k',
#    'expire_date': '2020-10-19T12:16:28.176Z'}},
#  {'model': 'sessions.session',
#   'pk': 'jv89foidd8p1arpuae4gj9ds8nxo74ba',
#   'fields': {'session_data': '.eJxVjEEOwiAQAP_C2ZCWwi549N43NLAsUjWQlPZk_Lsh6UGvM5N5i8Ufe16OxtuyRnEVSlx-WfD05NJFfPhyr5Jq2bc1yJ7I0zY518iv29n-DbJvuW9JWYPJowFHyI4IkiWMevCTZRVHwuAAgjMaUA0mBkCYAo-UGDWQ-HwB5Kk39g:1kLUba:52RkvTBqPifr1UMzGekhDAucMoKvi1Pg-Qpg8E4yJqo',
#    'expire_date': '2020-10-08T17:00:26.567Z'}},
#  {'model': 'sessions.session',
#   'pk': 'jx9kmpdxfpglewkf7znw35qim10d39z5',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kTqXR:VO7EwPXnnKIpEveTQukNFwVEhjudwOjcUa9T8ePY3to',
#    'expire_date': '2020-10-31T18:02:41.441Z'}},
#  {'model': 'sessions.session',
#   'pk': 'k3d67r1uqgz2nyxk2k5uz3lkwhnj62ri',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kjedp:6i9nESu-YqcKjdlzlWGC0Gaydnl8eI6lxFGg8hkW11M',
#    'expire_date': '2020-12-14T08:34:37.482Z'}},
#  {'model': 'sessions.session',
#   'pk': 'kbwu1vp5izbe85irz743sp38vlq0v8tk',
#   'fields': {'session_data': '.eJxVjDsOwjAQBe_iGll4_VFMSc8ZrN31GgeQI8VJFXF3iJQC2jczb1MJ16WmtcucxqwuCtTpdyPkp7Qd5Ae2-6R5ass8kt4VfdCub1OW1_Vw_w4q9vqty5BjJHGEWYYCZKKECMFwNFYg2iDgQvFsioCwNTZ4IuugnNF69qjeH_v1ODc:1kgk16:wHmDjEC_gKrD3iiRiBPm0fsriNuHZuR9OOipQkIA7hM',
#    'expire_date': '2020-12-06T07:42:36.898Z'}},
#  {'model': 'sessions.session',
#   'pk': 'kcfouqm4gg344it1mlgyff0h9arx04zq',
# ...
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6528,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 15:34:59',
#    'rf_id': '2E0025932BB3',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6529,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 15:35:00',
#    'rf_id': '2E0025932BB3',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6530,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 15:35:01',
#    'rf_id': '05004FF956E5',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6531,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 15:41:58',
#    'rf_id': '050052CFFB63',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6532,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 15:42:03',
#    'rf_id': '2E001DBF038F',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6533,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 15:57:23',
#    'rf_id': '050050707257',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6534,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 15:57:24',
#    'rf_id': '050050707257',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6535,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 15:57:26',
#    'rf_id': '050052831ECA',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6536,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 16:14:40',
#    'rf_id': '05004FF956E5',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6537,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 16:14:45',
#    'rf_id': '2E0025932BB3',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6538,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 16:30:35',
#    'rf_id': 'BD8F38C500CF',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6539,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 16:43:29',
#    'rf_id': '2E001DC208F9',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6540,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 16:43:32',
#    'rf_id': '2E001DA56EF8',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6541,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 16:43:36',
#    'rf_id': '2E0025932BB3',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6542,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 16:43:40',
#    'rf_id': '050050633B0D',
#    'gwId': '6'}},
#  {'model': 'school.attendance_api',
#   'pk': 6543,
#   'fields': {'school_code': 's003',
#    'attendance_timestamp': '20-Mar-21 16:43:44',
#    'rf_id': '05004FF956E5',
#    'gwId': '6'}},
#  {'model': 'school.attendance',
#   'pk': 7,
#   'fields': {'rf_id': '81239897AAB',
#    'name': 'Nobita Nobi',
#    'date': '2020-08-24',
#    'gwId': '10',
#    'intime': '13:19:18',
#    'outtime': '13:50:55',
#    'school_code': 'demo1',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '4'}},
#  {'model': 'school.attendance',
#   'pk': 8,
#   'fields': {'rf_id': '81239897AAB',
#    'name': 'Nobita Nobi',
#    'date': '2020-08-25',
#    'gwId': '10',
#    'intime': '15:03:23',
#    'outtime': '15:49:45',
#    'school_code': 'demo1',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '4'}},
#  {'model': 'school.attendance',
#   'pk': 9,
#   'fields': {'rf_id': 'AS45TY7UI8',
#    'name': 'mani',
#    'date': '2020-09-22',
#    'gwId': 'manual',
#    'intime': '05:48:52',
#    'outtime': '05:50:20',
#    'school_code': 'demo1',
#    'medium_name': 'English',
#    'class_name': '12',
#    'division_name': 'A',
#    'group_id': '4'}},
#  {'model': 'school.attendance',
#   'pk': 10,
#   'fields': {'rf_id': '6756AVCD',
#    'name': 'kumar',
#    'date': '2020-09-22',
#    'gwId': 'manual',
#    'intime': '08:18:46',
#    'outtime': None,
#    'school_code': 'demo1',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '4'}},
#  {'model': 'school.attendance',
#   'pk': 11,
#   'fields': {'rf_id': 'SD1234567',
#    'name': 'siddharth',
#    'date': '2020-11-22',
#    'gwId': 'manual',
#    'intime': '10:55:39',
#    'outtime': None,
#    'school_code': 'demo1',
#    'medium_name': 'English',
#    'class_name': '5',
#    'division_name': 'A',
#    'group_id': '4'}},
#  {'model': 'school.attendance',
#   'pk': 12,
#   'fields': {'rf_id': '2B00294CDF91',
#    'name': 'Satyaveer',
#    'date': '2021-02-08',
#    'gwId': '1',
#    'intime': '0:23:41',
#    'outtime': '4:00:24',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 13,
#   'fields': {'rf_id': '270019319F90',
#    'name': 'Manju',
#    'date': '2021-02-08',
#    'gwId': '1',
#    'intime': '0:23:47',
#    'outtime': '4:02:27',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': 'U.K.G',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 14,
#   'fields': {'rf_id': '0B00241A7045',
#    'name': 'sapna',
#    'date': '2021-02-08',
#    'gwId': '1',
#    'intime': '0:23:53',
#    'outtime': '4:01:59',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '2',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 15,
#   'fields': {'rf_id': '2B002A7F3F41',
#    'name': 'Aruna',
#    'date': '2021-02-08',
#    'gwId': '1',
#    'intime': '0:23:59',
#    'outtime': '4:02:30',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 16,
#   'fields': {'rf_id': '12aa12aa12aa',
#    'name': 'sumesh',
#    'date': '2021-02-08',
#    'gwId': '1',
#    'intime': '1:42:50',
#    'outtime': None,
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': 'Nursery',
#    'division_name': 'B',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 17,
#   'fields': {'rf_id': '3t3t3t3t3t3t',
#    'name': 'Ram',
#    'date': '2021-02-08',
#    'gwId': '1',
#    'intime': '4:05:24',
#    'outtime': None,
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': 'Nursery',
#    'division_name': 'B',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 18,
#   'fields': {'rf_id': '27001930CFC1',
#    'name': 'Rajesh',
#    'date': '2021-02-08',
#    'gwId': '1',
#    'intime': '0:05:24',
#    'outtime': '0:05:24',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '4',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 19,
#   'fields': {'rf_id': '2E002515253B',
#    'name': 'Hemlata',
#    'date': '2021-02-08',
#    'gwId': '1',
#    'intime': '0:05:24',
#    'outtime': '4:02:33',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '3',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 20,
#   'fields': {'rf_id': '2B00294CDF91',
#    'name': 'Satyaveer',
#    'date': '2021-02-09',
#    'gwId': '1',
#    'intime': '7:32:55',
#    'outtime': '5:20:25',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 21,
#   'fields': {'rf_id': '27001930CFC1',
#    'name': 'Rajesh',
#    'date': '2021-02-09',
#    'gwId': '1',
#    'intime': '7:33:02',
#    'outtime': '5:21:06',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '4',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 22,
#   'fields': {'rf_id': '0B00241A7045',
#    'name': 'sapna',
#    'date': '2021-02-09',
#    'gwId': '1',
#    'intime': '8:24:22',
#    'outtime': '8:58:46',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '2',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 23,
#   'fields': {'rf_id': '2E002515253B',
#    'name': 'Hemlata',
#    'date': '2021-02-09',
#    'gwId': '1',
#    'intime': '8:24:43',
#    'outtime': '8:57:22',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '3',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 24,
#   'fields': {'rf_id': '2B002A7F3F41',
#    'name': 'Aruna',
#    'date': '2021-02-09',
#    'gwId': '1',
#    'intime': '8:57:13',
#    'outtime': '8:57:14',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 25,
#   'fields': {'rf_id': '2B00294CDF91',
#    'name': 'Satyaveer',
#    'date': '2021-02-10',
#    'gwId': '1',
#    'intime': '09:01:25',
#    'outtime': '13:48:20',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 26,
#   'fields': {'rf_id': '27001930CFC1',
#    'name': 'Rajesh',
#    'date': '2021-02-10',
#    'gwId': '1',
#    'intime': '09:01:28',
#    'outtime': '09:01:34',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '4',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 27,
#   'fields': {'rf_id': '2B002A7F3F41',
#    'name': 'Aruna',
#    'date': '2021-02-10',
#    'gwId': '1',
#    'intime': '09:01:46',
#    'outtime': '09:01:48',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 28,
#   'fields': {'rf_id': '2E002515253B',
#    'name': 'Hemlata',
#    'date': '2021-02-10',
#    'gwId': '1',
#    'intime': '09:01:54',
#    'outtime': '09:01:55',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '3',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 29,
#   'fields': {'rf_id': '270019319F90',
#    'name': 'Manju',
#    'date': '2021-02-10',
#    'gwId': '1',
#    'intime': '09:02:04',
#    'outtime': None,
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': 'U.K.G',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 30,
#   'fields': {'rf_id': '0B00241A7045',
#    'name': 'sapna',
#    'date': '2021-02-10',
#    'gwId': '1',
#    'intime': '09:02:12',
#    'outtime': '09:02:13',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '2',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 31,
#   'fields': {'rf_id': '27001930CFC1',
#    'name': 'Rajesh kumari',
#    'date': '2021-02-10',
#    'gwId': '1',
#    'intime': '13:48:15',
#    'outtime': None,
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '4',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 32,
#   'fields': {'rf_id': '2B00294CDF91',
#    'name': 'Satyaveer',
#    'date': '2021-02-11',
#    'gwId': '1',
#    'intime': '07:38:17',
#    'outtime': '13:48:45',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 33,
#   'fields': {'rf_id': '27001930CFC1',
#    'name': 'Rajesh kumari',
#    'date': '2021-02-11',
#    'gwId': '1',
#    'intime': '07:38:39',
#    'outtime': '13:48:47',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '4',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 34,
#   'fields': {'rf_id': '2B002A7F3F41',
#    'name': 'Aruna',
#    'date': '2021-02-11',
#    'gwId': '1',
#    'intime': '09:01:19',
#    'outtime': '09:02:06',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 35,
#   'fields': {'rf_id': '2E002515253B',
#    'name': 'Hemlata',
#    'date': '2021-02-11',
#    'gwId': '1',
#    'intime': '09:01:22',
#    'outtime': '09:01:50',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '3',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 36,
#   'fields': {'rf_id': '27001930CFC1',
#    'name': 'Rajesh kumari',
#    'date': '2021-02-12',
#    'gwId': '1',
#    'intime': '07:35:53',
#    'outtime': '07:36:17',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '4',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 37,
#   'fields': {'rf_id': '2B00294CDF91',
#    'name': 'Satyaveer',
#    'date': '2021-02-12',
#    'gwId': '1',
#    'intime': '07:36:14',
#    'outtime': None,
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 38,
#   'fields': {'rf_id': '0B00241A7045',
#    'name': 'sapna',
#    'date': '2021-02-12',
#    'gwId': '1',
#    'intime': '08:20:15',
#    'outtime': None,
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '2',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 39,
#   'fields': {'rf_id': '2B002A7F3F41',
#    'name': 'Aruna',
#    'date': '2021-02-12',
#    'gwId': '1',
#    'intime': '08:55:15',
#    'outtime': '08:56:39',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 40,
#   'fields': {'rf_id': '2E002515253B',
#    'name': 'Hemlata',
#    'date': '2021-02-12',
#    'gwId': '1',
#    'intime': '08:56:33',
#    'outtime': None,
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '3',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 41,
#   'fields': {'rf_id': '0B00241A7045',
#    'name': 'sapna',
#    'date': '2021-02-13',
#    'gwId': '1',
#    'intime': '08:22:59',
#    'outtime': '09:03:00',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '2',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 42,
#   'fields': {'rf_id': '2E002515253B',
#    'name': 'Hemlata',
#    'date': '2021-02-13',
#    'gwId': '1',
#    'intime': '08:24:30',
#    'outtime': '09:03:04',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '3',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 43,
#   'fields': {'rf_id': '2B002A7F3F41',
#    'name': 'Aruna',
#    'date': '2021-02-13',
#    'gwId': '1',
#    'intime': '08:58:20',
#    'outtime': '09:02:54',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 44,
#   'fields': {'rf_id': '27001930CFC1',
#    'name': 'Rajesh kumari',
#    'date': '2021-02-13',
#    'gwId': '1',
#    'intime': '09:01:57',
#    'outtime': '09:01:58',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '4',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 45,
#   'fields': {'rf_id': '2B00294CDF91',
#    'name': 'Satyaveer',
#    'date': '2021-02-13',
#    'gwId': '1',
#    'intime': '09:02:03',
#    'outtime': None,
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 46,
#   'fields': {'rf_id': '2B00294CDF91',
#    'name': 'Satyaveer',
#    'date': '2021-02-15',
#    'gwId': '1',
#    'intime': '07:36:42',
#    'outtime': '07:37:28',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '8',
#    'division_name': 'A',
#    'group_id': '3'}},
#  {'model': 'school.attendance',
#   'pk': 47,
#   'fields': {'rf_id': '27001930CFC1',
#    'name': 'Rajesh kumari',
#    'date': '2021-02-15',
#    'gwId': '1',
#    'intime': '07:37:19',
#    'outtime': '07:37:31',
#    'school_code': 's003',
#    'medium_name': 'English',
#    'class_name': '4',
#    'division_name': 'A',
#    'group_id': '3'}},
#  ...]

# %%
{'model': 'school.posts',
  'pk': 1,
  'fields': {'title': 'hello',
              'body': 'kaise ho',
             'created_at': '2021-02-23T11:15:19Z',
             'post_image': 'images/cghjg5.jpeg'}}
# Out:
# {'model': 'school.posts',
#  'pk': 1,
#  'fields': {'title': 'hello',
#   'body': 'kaise ho',
#   'created_at': '2021-02-23T11:15:19Z',
#   'post_image': 'images/cghjg5.jpeg'}}

# %%
import json
from .models import Movie

# you can also keep this inside a view
with open('movie_data.json', encoding='utf-8') as data_file:
    json_data = json.loads(data_file.read())

    for movie_data in json_data:
        movie = Movie.create(**movie_data)
        # movie and genres created



dd=SchoolMaster.objects.values()


import json
from school.models import SchoolMaster

dd=SchoolMaster.objects.values()
with open('school_schoolmaster.json', encoding='utf-8') as data_file:
    json_data = json.loads(data_file.read())

    for school_schoolmaster in json_data:
         dd.update_or_create(school_schoolmaster)
       



import json
from school.models import SchoolMaster

dd=SchoolMaster.objects.values()
data_file=open('school_schoolmaster.json', encoding='utf-8')

json_data = json.loads(data_file.read())

for school_data in json_data:
        SchoolMaster.objects.update_or_create(school_data.items())
       


import json
from school.models import SchoolMaster

dd=SchoolMaster.objects.values()
data_file=open('school_schoolmaster.json', encoding='utf-8')

json_data = json.loads(data_file.read())

for school_data in json_data:
        SchoolMaster(school_data.items()).save()
       


import json
from school.models import SchoolMaster

dd=SchoolMaster.objects.values()
data_file=open('school_schoolmaster.json', encoding='utf-8')

json_data = json.loads(data_file.read())

for school_data in json_data:
        SchoolMaster(*school_data).save()
       



import json
from school.models import SchoolMaster

dd=SchoolMaster.objects.values()
data_file=open('school_schoolmaster.json', encoding='utf-8')

json_data = json.loads(data_file.read())

for school_data in json_data:
        SchoolMaster(**school_data).save()
       






for school_data in json_data:
        User(**school_data).save()


for school_data in json_data:
        Permission(**school_data).save()



from django.contrib.auth.models import User, Permission,Group
data_file=open('auth_group.json', encoding='utf-8')

for school_data in json_data:
        Group(**school_data).save()


auth_group_permissions.json


from django.contrib.auth.models import User, Permission,Group
data_file=open('auth_group_permissions.json', encoding='utf-8')
json_data = json.loads(data_file.read())
for school_data in json_data:
        Group(**school_data).save()





from django.contrib.auth.models import User, Permission


data_file=open('auth_user_groups.json', encoding='utf-8')
json_data = json.loads(data_file.read())


from django.contrib.auth.models import User
for school_data in json_data:
        user=User.objects.filter(id=school_data["id"])
        user.groups.add(school_data["group_id"])



data_file=open('school_ownermaster.json', encoding='utf-8')
json_data = json.loads(data_file.read())
for school_data in json_data:
        OwnerMaster(**school_data).save()


school_attendance


data_file=open('school_attendance.json', encoding='utf-8')
json_data = json.loads(data_file.read())
for school_data in json_data:
        Attendance(**school_data).save()


school_classmaster


data_file=open('school_classmaster.json', encoding='utf-8')
json_data = json.loads(data_file.read())
for school_data in json_data:
        ClassMaster(**school_data).save()





school_divisionmaster


data_file=open('school_divisionmaster.json', encoding='utf-8')
json_data = json.loads(data_file.read())
for school_data in json_data:
        DivisionMaster(**school_data).save()




school_mediummaster


data_file=open('school_mediummaster.json', encoding='utf-8')
json_data = json.loads(data_file.read())
for school_data in json_data:
        MediumMaster(**school_data).save()




school_parentsmaster


data_file=open('school_parentsmaster.json', encoding='utf-8')
json_data = json.loads(data_file.read())
for school_data in json_data:
        ParentsMaster(**school_data).save()



school_staffmaster


data_file=open('school_staffmaster.json', encoding='utf-8')
json_data = json.loads(data_file.read())
for school_data in json_data:
        StaffMaster(**school_data).save()



school_staffmaster


data_file=open('school_staffmaster.json', encoding='utf-8')
json_data = json.loads(data_file.read())
for school_data in json_data:
        StaffMaster(**school_data).save()


school_studentmaster


data_file=open('school_studentmaster.json', encoding='utf-8')
json_data = json.loads(data_file.read())
for school_data in json_data:
        StudentMaster(**school_data).save()




data_file=open('school_studentmaster.json', encoding='utf-8')
json_data = json.loads(data_file.read())
for school_data in json_data:
        try:
            StudentMaster(**school_data).save()
        except:pass





data_file=open('auth_user_groups.json', encoding='utf-8')
json_data = json.loads(data_file.read())


from django.contrib.auth.models import User
for school_data in json_data:
        user=User.objects.get(id=school_data["user_id"])
        group = Group.objects.get(id=school_data["group_id"])
        user.groups.add(group)
       








school_machine_update


data_file=open('school_school_machine_update.json', encoding='utf-8')
json_data = json.loads(data_file.read())
for school_data in json_data:
        school_machine_update(**school_data).save()





from django.contrib.auth.models import Group
group = Group.objects.get(id=1)
user=User.objects.get(id=1)
user.groups.add(group)




data_file=open('auth_user_groups.json', encoding='utf-8')
json_data = json.loads(data_file.read())


from django.contrib.auth.models import User
for school_data in json_data:
        user=User.objects.get(id=school_data["user_id"])
        group = Group.objects.get(id=school_data["group_id"])
        user.groups.add(group)

# %%
dd={'address': 'Gopalganj',
 'affiliated_by': 'CBSC',
 'city': 'Gopalganj',
 'created_by': None,
 'created_on': '2021-04-10 16:49:30.484785',
 'email': 'delhipublicschool45@gmail.com',
 'image': 'images/IMG-20210317-WA0031.jpg',
 'logo_of_school': '',
 'mobile': 7352813725,
 'password': '12345',
 'pincode': '841437',
 'principal_sign_image': 'images/IMG20210317115834.jpg',
 'registration_number': 'Br27895v',
 'school_code': 'sbsy36',
 'school_id': 36,
 'school_name': 'Delhi public school'}

# %%
l=[]
for key,val in dd.items():
    l.append(f"{key} = {val} ,")
    
print(l)
# Out:
# ['address = Gopalganj ,', 'affiliated_by = CBSC ,', 'city = Gopalganj ,', 'created_by = None ,', 'created_on = 2021-04-10 16:49:30.484785 ,', 'email = delhipublicschool45@gmail.com ,', 'image = images/IMG-20210317-WA0031.jpg ,', 'logo_of_school =  ,', 'mobile = 7352813725 ,', 'password = 12345 ,', 'pincode = 841437 ,', 'principal_sign_image = images/IMG20210317115834.jpg ,', 'registration_number = Br27895v ,', 'school_code = sbsy36 ,', 'school_id = 36 ,', 'school_name = Delhi public school ,']

# %%
dict(x=10,y=20)
# Out:
# {'x': 10, 'y': 20}

# %%
def data(*x):
    return x

# %%
dd.items()
# Out:
# dict_items([('address', 'Gopalganj'), ('affiliated_by', 'CBSC'), ('city', 'Gopalganj'), ('created_by', None), ('created_on', '2021-04-10 16:49:30.484785'), ('email', 'delhipublicschool45@gmail.com'), ('image', 'images/IMG-20210317-WA0031.jpg'), ('logo_of_school', ''), ('mobile', 7352813725), ('password', '12345'), ('pincode', '841437'), ('principal_sign_image', 'images/IMG20210317115834.jpg'), ('registration_number', 'Br27895v'), ('school_code', 'sbsy36'), ('school_id', 36), ('school_name', 'Delhi public school')])
